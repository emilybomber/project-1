# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
#Adding CSV_files
gen_pop_df = pd.read_csv("Resources/gdp_decomposition_pop_weighted_average.csv")
hour_worked_df = pd.read_csv("Resources/gdp_over_hours_worked.csv")
hour_worked_df.head()
# Out:
#   iso2c  year     country iso3c          pop  labor_force  gdp_ppp_c  gdp_ppp  \
# 0    1A  1980  Arab World   ARB  167707208.0          NaN        NaN      NaN
# 1    1A  1981  Arab World   ARB  173118753.0          NaN        NaN      NaN
# 2    1A  1982  Arab World   ARB  178587926.0          NaN        NaN      NaN
# 3    1A  1983  Arab World   ARB  184342569.0          NaN        NaN      NaN
# 4    1A  1984  Arab World   ARB  190162096.0          NaN        NaN      NaN
#
#             gdp         gdp_c  ...  employed  total_hours_alternative  \
# 0  4.598046e+11  8.594801e+11  ...       NaN                      NaN
# 1  4.748121e+11  8.884793e+11  ...       NaN                      NaN
# 2  4.445759e+11  8.148883e+11  ...       NaN                      NaN
# 3  4.184621e+11  7.643004e+11  ...       NaN                      NaN
# 4  4.258994e+11  7.744464e+11  ...       NaN                      NaN
#
#    gdp_over_k_hours_worked  gdp_ppp_over_k_hours_worked  gdp_over_pop  \
# ...

# %%
#cleaning data of hours worked
hour_worked_df.dropna(how='any')
us_hours_worked_df = hour_worked_df[hour_worked_df['country']== "United States"]
print(us_hours_worked_df)
# Out:
#      iso2c  year        country iso3c          pop  labor_force     gdp_ppp_c  \
# 9460    US  1980  United States   USA  227225000.0          NaN           NaN
# 9461    US  1981  United States   USA  229466000.0          NaN           NaN
# 9462    US  1982  United States   USA  231664000.0          NaN           NaN
# 9463    US  1983  United States   USA  233792000.0          NaN           NaN
# 9464    US  1984  United States   USA  235825000.0          NaN           NaN
# 9465    US  1985  United States   USA  237924000.0          NaN           NaN
# 9466    US  1986  United States   USA  240133000.0          NaN           NaN
# 9467    US  1987  United States   USA  242289000.0          NaN           NaN
# 9468    US  1988  United States   USA  244499000.0          NaN           NaN
# 9469    US  1989  United States   USA  246819000.0          NaN           NaN
# 9470    US  1990  United States   USA  249623000.0  127352631.0  1.009762e+13
# ...

# %%
us_hours_worked_df.info()
us_hours_worked_df.dropna(how="all", inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, 9460 to 9502
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   iso2c                          43 non-null     object
#  1   year                           43 non-null     int64
#  2   country                        43 non-null     object
#  3   iso3c                          43 non-null     object
#  4   pop                            43 non-null     float64
#  5   labor_force                    33 non-null     float64
#  6   gdp_ppp_c                      33 non-null     float64
#  7   gdp_ppp                        33 non-null     float64
#  8   gdp                            43 non-null     float64
#  9   gdp_c                          43 non-null     float64
#  10  unemployment_r                 32 non-null     float64
#  11  pop_over_65                    43 non-null     float64
# ...
