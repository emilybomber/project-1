# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import PercentFormatter
from scipy import stats
import numpy as np
import pandas as pd

# %% [markdown]
# ### US data

# %%
#read the file
gdp=pd.read_csv("resources/gdp_over_hours_worked.csv")
gdp.head()
# Out:
#   iso2c  year     country iso3c          pop  labor_force  gdp_ppp_c  gdp_ppp  \
# 0    1A  1980  Arab World   ARB  167707208.0          NaN        NaN      NaN
# 1    1A  1981  Arab World   ARB  173118753.0          NaN        NaN      NaN
# 2    1A  1982  Arab World   ARB  178587926.0          NaN        NaN      NaN
# 3    1A  1983  Arab World   ARB  184342569.0          NaN        NaN      NaN
# 4    1A  1984  Arab World   ARB  190162096.0          NaN        NaN      NaN
#
#             gdp         gdp_c  ...  employed  total_hours_alternative  \
# 0  4.598046e+11  8.594801e+11  ...       NaN                      NaN
# 1  4.748121e+11  8.884793e+11  ...       NaN                      NaN
# 2  4.445759e+11  8.148883e+11  ...       NaN                      NaN
# 3  4.184621e+11  7.643004e+11  ...       NaN                      NaN
# 4  4.258994e+11  7.744464e+11  ...       NaN                      NaN
#
#    gdp_over_k_hours_worked  gdp_ppp_over_k_hours_worked  gdp_over_pop  \
# ...

# %%
#Pick the colums
gdp_columns_picked=gdp[["year", "country","pop","labor_force","unemployment_r", "pop_over_65", "employment_rate" ]]
gdp_columns_picked.head()
# Out:
#    year     country          pop  labor_force  unemployment_r  pop_over_65  \
# 0  1980  Arab World  167707208.0          NaN             NaN     3.383674
# 1  1981  Arab World  173118753.0          NaN             NaN     3.357888
# 2  1982  Arab World  178587926.0          NaN             NaN     3.332335
# 3  1983  Arab World  184342569.0          NaN             NaN     3.310055
# 4  1984  Arab World  190162096.0          NaN             NaN     3.296280
#
#    employment_rate
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#filter for US and years after 1990
US_gdp_columns_fil=gdp_columns_picked[(gdp_columns_picked['country']=='United States') & (gdp_columns_picked['year']>=1992)]
US_gdp_columns_fil.head()
# Out:
#       year        country          pop  labor_force  unemployment_r  \
# 9472  1992  United States  256514000.0  130387356.0            7.50
# 9473  1993  United States  259919000.0  131792391.0            6.90
# 9474  1994  United States  263126000.0  134076659.0            6.12
# 9475  1995  United States  266278000.0  135975697.0            5.65
# 9476  1996  United States  269394000.0  138055157.0            5.45
#
#       pop_over_65  employment_rate
# 9472    12.396846         70.80585
# 9473    12.427348         71.20782
# 9474    12.483979         72.00175
# 9475    12.543634         72.53490
# 9476    12.550368         72.85875

# %%
#Rename the columns
US_gdp_columns_fil.rename(columns={'year': 'Year', 'country': 'Country',
                                   'labor_force' : 'Labor Force', 
                                   'pop' : 'Population', 
                                   'pop_over_65' : 'Population over 65',  
                                   'employment_rate' : 'Employment Rate', 
                                   'unemployment_r' : 'Unemployment Rate'}, inplace=True)
US_gdp_columns_fil.head()
# Out:
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\427409130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   US_gdp_columns_fil.rename(columns={'year': 'Year', 'country': 'Country',
#       Year        Country   Population  Labor Force  Unemployment Rate  \
# 9472  1992  United States  256514000.0  130387356.0               7.50
# 9473  1993  United States  259919000.0  131792391.0               6.90
# 9474  1994  United States  263126000.0  134076659.0               6.12
# 9475  1995  United States  266278000.0  135975697.0               5.65
# 9476  1996  United States  269394000.0  138055157.0               5.45
#
#       Population over 65  Employment Rate
# 9472           12.396846         70.80585
# 9473           12.427348         71.20782
# 9474           12.483979         72.00175
# ...

# %% [markdown]
# ### G7 data

# %%
gdp=pd.read_csv("resources/gdp_over_hours_worked.csv")
gdp.head()
# Out:
#   iso2c  year     country iso3c          pop  labor_force  gdp_ppp_c  gdp_ppp  \
# 0    1A  1980  Arab World   ARB  167707208.0          NaN        NaN      NaN
# 1    1A  1981  Arab World   ARB  173118753.0          NaN        NaN      NaN
# 2    1A  1982  Arab World   ARB  178587926.0          NaN        NaN      NaN
# 3    1A  1983  Arab World   ARB  184342569.0          NaN        NaN      NaN
# 4    1A  1984  Arab World   ARB  190162096.0          NaN        NaN      NaN
#
#             gdp         gdp_c  ...  employed  total_hours_alternative  \
# 0  4.598046e+11  8.594801e+11  ...       NaN                      NaN
# 1  4.748121e+11  8.884793e+11  ...       NaN                      NaN
# 2  4.445759e+11  8.148883e+11  ...       NaN                      NaN
# 3  4.184621e+11  7.643004e+11  ...       NaN                      NaN
# 4  4.258994e+11  7.744464e+11  ...       NaN                      NaN
#
#    gdp_over_k_hours_worked  gdp_ppp_over_k_hours_worked  gdp_over_pop  \
# ...

# %%
#Pick the colums
G7_gdp_columns_picked=gdp[["year", "country","pop","unemployment_r","gdp"]]
G7_gdp_columns_picked.head()
# Out:
#    year     country          pop  unemployment_r           gdp
# 0  1980  Arab World  167707208.0             NaN  4.598046e+11
# 1  1981  Arab World  173118753.0             NaN  4.748121e+11
# 2  1982  Arab World  178587926.0             NaN  4.445759e+11
# 3  1983  Arab World  184342569.0             NaN  4.184621e+11
# 4  1984  Arab World  190162096.0             NaN  4.258994e+11

# %%
#Rename the columns
G7_gdp_columns_picked.rename(columns={'year': 'Year', 'country': 'Country', 'pop' : 'Population', 
                                      'unemployment_r' : 'Unemployment Rate', 'gdp': 'GDP'}, inplace=True)
G7_gdp_columns_picked.head()
# Out:
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\2966441997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   G7_gdp_columns_picked.rename(columns={'year': 'Year', 'country': 'Country', 'pop' : 'Population',
#    Year     Country   Population  Unemployment Rate           GDP
# 0  1980  Arab World  167707208.0                NaN  4.598046e+11
# 1  1981  Arab World  173118753.0                NaN  4.748121e+11
# 2  1982  Arab World  178587926.0                NaN  4.445759e+11
# 3  1983  Arab World  184342569.0                NaN  4.184621e+11
# 4  1984  Arab World  190162096.0                NaN  4.258994e+11

# %%
#filter for G7 countries and years after 1992
G7_gdp_columns_data=G7_gdp_columns_picked[(G7_gdp_columns_picked['Year']>=1992)&(G7_gdp_columns_picked['Country']=='Canada')|(G7_gdp_columns_picked['Country']=='France') | (G7_gdp_columns_picked['Country']=='Germany') | (G7_gdp_columns_picked['Country']=='Italy') | (G7_gdp_columns_picked['Country']=='Japan') | (G7_gdp_columns_picked['Country']=='United Kingdom') | (G7_gdp_columns_picked['Country']=='United States') ]
G7_gdp_columns_data.head()
# Out:
#       Year Country  Population  Unemployment Rate           GDP
# 1603  1992  Canada  28371264.0              11.20  5.943761e+11
# 1604  1993  Canada  28684764.0              11.38  5.790590e+11
# 1605  1994  Canada  29000663.0              10.40  5.799443e+11
# 1606  1995  Canada  29302311.0               9.49  6.059410e+11
# 1607  1996  Canada  29610218.0               9.62  6.305980e+11

# %%
G7_gdp_columns_data["GDP in Trillions"]=round(G7_gdp_columns_data["GDP"]/1000000000,2)
G7_gdp_columns_data.drop('GDP', axis=1, inplace=True)
G7_gdp_columns_data
# Out:
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\3154173925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   G7_gdp_columns_data["GDP in Trillions"]=round(G7_gdp_columns_data["GDP"]/1000000000,2)
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\3154173925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   G7_gdp_columns_data.drop('GDP', axis=1, inplace=True)
#       Year        Country   Population  Unemployment Rate  GDP in Trillions
# 1603  1992         Canada   28371264.0             11.200            594.38
# ...

# %%
unique_countries = G7_gdp_columns_data['Country'].unique()
colors = {'France':'blue', 'Germany':'yellow', 'Italy':'green', 'Japan':'orange', 
         'United Kingdom':'purple', 'United States':'pink','Canada':'red'}

for country in unique_countries:
    country_data = G7_gdp_columns_data[G7_gdp_columns_data['Country'] == country]
    plt.plot(country_data['Year'], country_data['GDP in Trillions'], marker='o', linestyle='-', 
             label=country, color=colors[country])

plt.xlabel('Year')
plt.ylabel('GDP in Trillions')
plt.title('G7 GDP')
plt.legend()
plt.show()

# %%
unique_countries = G7_gdp_columns_data['Country'].unique()
colors = {'France':'blue', 'Germany':'yellow', 'Italy':'green', 'Japan':'orange', 
         'United Kingdom':'purple', 'United States':'pink','Canada':'red'}

for country in unique_countries:
    country_data = G7_gdp_columns_data[G7_gdp_columns_data['Country'] == country]
    plt.plot(country_data['Year'], country_data['Population'], marker='o', linestyle='-', 
             label=country, color=colors[country])

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('G7 Population over 20 years')
plt.legend()
plt.show()

# %%
data_2022 = G7_gdp_columns_data[G7_gdp_columns_data['Year']==2022]
plt.figure(figsize=(10, 6))
colors=['red', 'yellow', 'blue', 'green', 'orange', 'purple', 'pink']
plt.pie(data_2022['GDP in Trillions'], labels=data_2022['Country'], autopct='%1.1f%%', startangle=290, colors=colors)
plt.title('GDP Distribution by G7 Countries in 2022')
plt.show()

# %%
#fig, ax1= plt.subplots()

plt.bar(data_2022['Country'], data_2022['Unemployment Rate'], color=['red', 'yellow', 'blue', 'green', 
                                                                     'orange', 'purple', 'pink'])

plt.xlabel('Country')
plt.ylabel('Unemployment Rate (%)')
plt.tick_params('y', colors='red')
plt.xticks(rotation=45)
plt.yticks(range(0,16), labels=(f'{i}%' for i in range(0,16)))
#plt.yticks(f'{i}%' for i in range(0,9))
plt.title('Unemployment Rate per Country in 2022')
plt.show()

# %%
#Pick Top 10 GDP Countries 
Top_10_gdp_country_2022=G7_gdp_columns_picked[(G7_gdp_columns_picked['Year']>=1992)&(G7_gdp_columns_picked['Country']=='United States')|(G7_gdp_columns_picked['Country']=='China') | (G7_gdp_columns_picked['Country']=='Japan') | (G7_gdp_columns_picked['Country']=='Germany') | (G7_gdp_columns_picked['Country']=='India') | (G7_gdp_columns_picked['Country']=='United Kingdom') | (G7_gdp_columns_picked['Country']=='France') | (G7_gdp_columns_picked['Country']=='Russian Federation')| (G7_gdp_columns_picked['Country']=='Canada')| (G7_gdp_columns_picked['Country']=='Italy')]
Top_10_gdp_country_2022["GDP in Trillions"]=round(Top_10_gdp_country_2022["GDP"]/1000000000,2)
Top_10_gdp_country_2022.drop('GDP', axis=1, inplace=True)
Top_10_gdp_country_2022
# Out:
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\2294487072.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top_10_gdp_country_2022["GDP in Trillions"]=round(Top_10_gdp_country_2022["GDP"]/1000000000,2)
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\2294487072.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top_10_gdp_country_2022.drop('GDP', axis=1, inplace=True)
#       Year        Country   Population  Unemployment Rate  GDP in Trillions
# 1591  1980         Canada   24515667.0                NaN            274.77
# ...

# %%
Top_10_data_2022 = Top_10_gdp_country_2022[Top_10_gdp_country_2022['Year']==2022]
plt.figure(figsize=(10, 6))
colors=['red', 'yellow', 'blue', 'green', 'orange', 'purple', 'pink', 'brown', 'lime', 'aqua', 'gray']
plt.pie(Top_10_data_2022['GDP in Trillions'], labels=Top_10_data_2022['Country'], autopct='%1.1f%%', startangle=290, colors=colors)
plt.title('Top 10 GDP Countries in 2022')
plt.show()

# %%
#Pick top 10 GDP countries after 1992 
Top_10_gdp_country_20_years=G7_gdp_columns_picked.loc[(G7_gdp_columns_picked['Year']>=1992)]
Top_10_gdp_country_20_years
# Out:
#        Year     Country   Population  Unemployment Rate           GDP
# 12     1992  Arab World  236598334.0          11.950448  4.738113e+11
# 13     1993  Arab World  242994250.0          12.661873  4.827643e+11
# 14     1994  Arab World  249596194.0          12.738380  5.077649e+11
# 15     1995  Arab World  255803349.0          13.216999  5.560464e+11
# 16     1996  Arab World  261953764.0          12.266322  6.141861e+11
# ...     ...         ...          ...                ...           ...
# 11555  2022     Namibia    2567012.0          20.846000  1.260744e+10
# 11556  2022     Namibia    2567012.0          20.846000  1.260744e+10
# 11557  2022     Namibia    2567012.0          20.846000  1.260744e+10
# 11558  2022     Namibia    2567012.0          20.846000  1.260744e+10
# 11559  2022     Namibia    2567012.0          20.846000  1.260744e+10
#
# [8356 rows x 5 columns]

# %%
plt.figure(figsize = (15, 10))
unique_countries = Top_10_gdp_country_2022['Country'].unique()
colors = {'United States':'aqua', 'China':'yellow', 'Japan':'brown', 'Germany':'blue', 'India':'purple', 
         'United Kingdom':'orange', 'France':'green', 'Russian Federation':'lime','Canada':'red', 'Italy':'pink'}

for country in unique_countries:
    country_data = Top_10_gdp_country_2022[Top_10_gdp_country_2022['Country'] == country]
    plt.plot(country_data['Year'], country_data['GDP in Trillions'], marker='o', linestyle='-', 
             label=country, color=colors[country])

plt.xlabel('Year')
plt.ylabel('GDP in Trillions')
plt.title('Top 10 GDP')
plt.legend()
plt.show()

# %% [markdown]
# ##OKUN'S LAW
# ### Exploring GDP and Unemploywntr
# #### Rapid Growth of GDP is correcled with decressed unemploymetn rates

# %%
#OkensLaw 
#Make Rates of Unemployment (Change of unemployement and subtrack)
df_pivot = Top_10_gdp_country_2022.pivot(index='Year', columns='Country', values='Unemployment Rate')
plt.figure(figsize=(12, 8))
for country in Top_10_gdp_country_2022['Country'].unique():
    plt.plot(df_pivot.index, df_pivot[country], label=country)
plt.title("Unemployment Change Over 20 Years for the 10 Highest GDP's")
plt.xlabel('Year')
plt.ylabel('Unemployment Rates (%)')
plt.grid(True)
plt.legend(loc="upper left")
plt.show()

# %%
# Sort the data by Country and Year
Top_10_gdp_country_2022.sort_values(by=['Country', 'Year'], inplace=True)

# Calculate GDP growth rate
Top_10_gdp_country_2022['GDP Growth Rate'] = (
    Top_10_gdp_country_2022.groupby('Country')['GDP in Trillions'].pct_change() * 100
)

# Pivot the data for easier plotting
df_pivot_growth_rate = Top_10_gdp_country_2022.pivot(index='Year', columns='Country', values='GDP Growth Rate')

# Plot the GDP growth rate
plt.figure(figsize=(12, 8))
for country in Top_10_gdp_country_2022['Country'].unique():
    plt.plot(df_pivot_growth_rate.index, df_pivot_growth_rate[country], label=country)

plt.title("GDP Growth Rate Over 20 Years for the 10 Highest GDP Countries")
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')
plt.grid(True)
plt.legend(loc="upper left")
plt.show()
# Out:
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\1182906103.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top_10_gdp_country_2022.sort_values(by=['Country', 'Year'], inplace=True)
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\1182906103.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top_10_gdp_country_2022['GDP Growth Rate'] = (

# %%
# Sort the data by Country and Year
Top_10_gdp_country_2022.sort_values(by=['Country', 'Year'], inplace=True)

# Calculate the GDP gap using Okun's Law
natural_unemployment_rate = 5.0 

Top_10_gdp_country_2022['GDP Gap'] = 2 * (Top_10_gdp_country_2022['Unemployment Rate'] - natural_unemployment_rate)

# Plot a scatter plot
plt.figure(figsize=(12, 8))
for country in Top_10_gdp_country_2022['Country'].unique():
    plt.scatter(Top_10_gdp_country_2022[Top_10_gdp_country_2022['Country'] == country]['Unemployment Rate'],
                Top_10_gdp_country_2022[Top_10_gdp_country_2022['Country'] == country]['GDP Gap'],
                label=country)

plt.axhline(0, color='black', linestyle='--', linewidth=1, label='Zero GDP Gap')  # Adding a line at zero for reference
plt.title("GDP Gap Against Unemployment Rate (Okun's Law)")
plt.xlabel('Unemployment Rate (%)')
plt.ylabel('GDP Gap')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\895825918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top_10_gdp_country_2022.sort_values(by=['Country', 'Year'], inplace=True)
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\895825918.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top_10_gdp_country_2022['GDP Gap'] = 2 * (Top_10_gdp_country_2022['Unemployment Rate'] - natural_unemployment_rate)

# %%
# Out:
# C:\Users\eannb\AppData\Local\Temp\ipykernel_3920\3698597319.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GDP Growth Rate'] = df.groupby('Country')['GDP'].pct_change() * 100
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# ...
